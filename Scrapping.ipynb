# %% [markdown]
# Notre objectif est de scraper suffisamment de données sous la forme de fichiers sons (*.mp3* par exemple) pour pouvoir entraîner ensuite un ou plusieurs classificateurs de genres musicaux.
#
# Spotify dispose d'une API très pratique pour les développeurs, leur permettant de récupérer de nombreuses informations sur les musiques hébergées par la plateforme. Il existe également une bibliothèque Python, [spotipy](https://spotipy.readthedocs.io/en/2.16.1/), qui permet d'utiliser très facilement cette API via Python.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
import numpy as np
import time
import pickle
import random as rd
import os

# %% [markdown]
# Pour accéder à l'API de Spotify, il est nécessaire de posséder des identifiants clients, obtenables avec un compte Spotify. Puisque nous en possédons un, nous avons stocké les informations sur un fichier que l'on extrait ensuite pour accéder à la base de données Spotify.

# %%
with open('Data//spotify_cids', 'r') as id_file :
    client_id, secret_id = id_file.read().split(':')

# %% [markdown]
# Les deux lignes suivantes nous authentifient auprès de Spotify et nous permettent d'accéder aux données.

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = client_id, client_secret = secret_id)

sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# Spotipy dispose d'une commande *search* qui permet de retourner un certain nombre d'objets (artistes, albums, chansons, podcasts, playlists...) à partir d'un terme passé en argument. Le nombre maximum d'objets retournés par requête est de 50.
#
# Il nous faut d'abord définir une liste de genres musicaux à scrapper. Les genres doivent être suffisamment généraux pour regrouper de nombreuses chansons, suffisamment différent entre eux, et également aisément différenciable par un humain.
#
# Nous nous sommes finalement fixés sur 9 genres différents :
#
#     Rock, Jazz, Blues, Classique, Country, Hip-Hop, Disco, Metal et House/Electro
#
# Notre démarche est donc la suivante :
#
#   1. Récupérer un grand nombre de musiques via la commande search
#   2. Associer à chaque chanson son genre musical (Spotify n'associe pas un genre musical à chaque musique, mais la plupart des artistes sont associés à une liste de genres musicaux. L'astuce pour retrouver le genre d'une chanson est donc d'aller récupérer le genre "général" du créateur de la musique).
#   4. Récupérer pour chaque chanson quelques features proposées directement par Spotify (danceability, energy...), dont nous mesurerons la pertinence pour la classification
#   5. Récupérer un extrait *.mp3* ou autre de quelques dizaines de secondes pour extraire nous même de nouvelles features

# %% [markdown]
# Un problème que nous avons rencontré est que les recherches sont généralement limitées à 2000 résultats, ce qui est insuffisant pour notre projet. Nous choisissons donc d'utiliser une liste de termes à rechercher, pour obtenir 2000 musiques différentes sur chacun de ces termes.

# %%
def check_genres(tracks, database, spotify_module):
    """
    La fonction prend en entrée une liste de musiques *tracks*, ainsi qu'un dictionnaire *database* 
    Elle retourne le dictionnaire *database* auquel on a ajouté les musiques de *tracks* pour lesquelles au moins 
    un genre a pu être associé
    """
    
    for track in tracks :
        
        # Récupère le dictionnaire avec les infos de l'artiste principal de la musique
        artistDict = track['artists'][0]
        
        # Récupère les genres musicaux associés à l'artiste de la musique
        # La fonction .artist retourne un dictionnaire contenant de nombreuses informations
        # ici c'est la clé "genres" qui nous intéresse
        # pour identifier l'artiste de la chanson, on utilise ici l'url spotify de la musique
        track_genres = spotify_module.artist(artistDict["external_urls"]["spotify"])["genres"]
        
        # Certains artistes n'ont aucun genre associés et la liste est donc vide
        # On ajoute le morceau à la base de données que si au moins un genre est associé à l'artiste
        if track_genres :
            
            trackInfos = {'track_name' : track['name'],
                          'track_artists' : artistDict['name'],
                          'genres' : track_genres}
            
            trackId = track['id']
            
            # On ajoute toutes les infos à notre base de données en utilisant l'id du morceau comme clé
            # Ainsi, si la chanson a déjà été retourné lors d'une autre requête, elle n'apparaitra pas en doublon dans le dictionnaire
            database[trackId] = trackInfos
            
    return database
            
        

def create_database (searchTerms, spotify_module, savename, querySize = 50):
    """
    La fonction prend en argument *searchTerms* une liste de string à utiliser pour effectuer les requêtes
    Elle prend également le module spotipy, ainsi que le nombre de chansons renvoyés à chaque requête *querySize*
    *savename* correspond au nom du fichier dans lequel le dictionnaire des données est sauvegardé
    """

    # tracksId est le dictionnaire dans lequel on va stocker toutes les informations des pistes 
    # qui nous intéressent pour la première étape du scrapping
    tracksId = dict()
    
    overall_start = time.time()
    
    # Tant que la base de données n'a pas le taille souhaitée et qu'il reste des termes, les requêtes continuent
    while searchTerms :
        
        searchTerm = searchTerms.pop(0)
        
        start_time = time.time()
        for offset in range(0, 2000, 50):
            
            # On récupère *limit* (=querySize) chanson par requête. 
            # Le paramètre type spécifie que l'on veut des objets "tracks" et pas des artistes ou des playlists par ex
            # Le paramètre offset spécifie le décalage que l'on veut dans la liste des résultats de la requête 
            # (puisqu'on ne peut avoir que 50 chansons par requête mais une requête propose en général 2000 résultats)
            queryResults = spotify_module.search(searchTerm, limit = querySize, 
                                                 type='track', offset=offset)
            
            trackList = queryResults['tracks']['items']
            
            # On utilise le résultat de la recherche pour alimenter la base de données
            tracksId = check_genres(trackList, tracksId, spotify_module = spotify_module)
            
        print('%s done in %.2f minutes' % (searchTerm, (time.time() - start_time)/60))
        print('%d tracks scrapped. Total time : %.2f\n' % (len(tracksId), (time.time() - overall_start)/60))
        
        # A chaque searchTerm, on sauvegarde les données scrappées dans un fichier pickle pour ne pas perdre le travail
        with open('%s.pickle' % savename, 'wb') as dict_file:
            pickle.dump(tracksId, dict_file, protocol=pickle.HIGHEST_PROTOCOL)    
            
    return tracksId

# %% [markdown]
# On définit une liste de termes à chercher qui correspond aux genres que l'on veut obtenir (certains apparaissent plus souvent car ils sont plus difficiles à obtenir, et il nous faut une base de données équilibrées).
#
# On ajoute également certains termes génériques pour les données.

# %%
searchTerms = ['Essentials', 'Best of','2010', '1990', '1980', '1970',
                'Classical', 'Mozart', 'Romance',
               'Country', 'Wild Country', 'Country Gold',
               'Rock', 'Rock and Roll',
               'Jazz', 'Jazz Vibes', 'Jazzy',
               'Hip Hop', 'Rap',
               'Blues', 'Roots', 'Acoustic Blues'
               'Disco', 'Fever', 'Dance', 'Funk',
               'Metal', 'Heavy Metal', 'Thrash Metal',
               'House', 'Electro', 'edm', 'techno']

# %%
# 2000 requêtes par terme correspondent à environ 3 minutes 
#tracksDict = create_database(searchTerms, sp, "Data//raw_scrap")

# %% [markdown]
# On dispose maintenant d'un certain nombre de chansons avec une liste de genres associés. Il faut cependant réussir à extraire de cette liste un genre global correspondant à l'un de nos 9 genres (quand c'est possible), et équilibrer la base en ajoutant le même nombre de musiques pour chaque genre

# %%
# On récupère éventuellement les données sauvegardés dans le fichier créé précédemment
with open('Data//raw_scrap.pickle', 'rb') as dict_file:
    tracksDict = pickle.load(dict_file)

# %%
genres = ['rock', 'metal', 'jazz', 'blues', 'disco', 'house', 'classical', 'hip hop', 'country']

# %%
# Une simple fonction qui permet de rassembler tous les sous-genres obtenus par le scraping réalisé, 
# afin de réfléchir à comment les organiser dans les 9 genres globaux que nous avons fixés
def count_subgenres (tracksDict):
    
    subgenresDict = {}
    for tracks in tracksDict.values():
        for subgenre in tracks['genres'] :
            subgenresDict[subgenre] = subgenresDict.setdefault(subgenre, 0) + 1
            
    return subgenresDict

subgenresDict = count_subgenres(tracksDict)
print(len(subgenresDict))
# Out:
# 2903

# %% [markdown]
# On compte près de 3 000 sous-genres différents, qu'il va être difficile de classer. On peut cependant essayer déjà de les regrouper naïvement en vérifiant qu'il contienne un des mots de la liste *genres*, ainsi que quelques autres mots clés puisque certains genres (classique, disco) sont sous représentés.

# %%
genresAugmented = genres + ['romantic', 'baroque',
                            'funk', 'dance',
                            'electro', 'edm', 'techno', 'trance',
                            'roots', 'soul',
                            'bluegrass', 'americana']

# %%
genresToSubgenres = {genre : [] for genre in genresAugmented}

for subgenre in subgenresDict.keys():
    for genre in genresAugmented :
        if genre in subgenre :
            genresToSubgenres[genre].append(subgenre)

for genre, subgenresList in genresToSubgenres.items():
    print(genre, len(subgenresList))
# Out:
# rock 225
# metal 214
# jazz 88
# blues 37
# disco 11
# house 69
# classical 48
# hip hop 108
# country 35
# romantic 12
# baroque 6
# funk 35
# dance 31
# electro 62
# edm 17
# techno 36
# trance 26
# roots 10
# soul 30
# bluegrass 7
# americana 19

# %% [markdown]
# On obtient peut être une liste satisfaisante de sous-genres à partir de ces genres "élargis", construisons de nouveaux objets pour le vérifier

# %%
subgenresToGenre = {}

for genre, subgenresList in genresToSubgenres.items():
    
    for subgenre in subgenresList :
        
        if genre == 'romantic' or genre == 'baroque' :
            subgenresToGenre[subgenre] = 'classical'
            
        elif genre == 'bluegrass' or genre == 'americana' :
            subgenresToGenre[subgenre] = 'country'
            
        elif genre == 'soul' or genre == 'roots':
            subgenresToGenre[subgenre] = 'blues'
            
        elif genre == 'electro' or genre == 'edm' or genre == 'techno' or genre == 'trance' :
            subgenresToGenre[subgenre] = 'house'
        
        elif genre == 'funk' or genre == 'dance':
            subgenresToGenre[subgenre] = 'disco'
            
        else :
            subgenresToGenre[subgenre] = genre

subgenresToGenre
# Out:
# {'classic garage rock': 'rock',
#  'classic rock': 'rock',
#  'folk rock': 'rock',
#  'psychedelic rock': 'rock',
#  'rock': 'rock',
#  'rock-and-roll': 'rock',
#  'soft rock': 'rock',
#  'christian alternative rock': 'rock',
#  'country rock': 'country',
#  'yacht rock': 'rock',
#  'album rock': 'rock',
#  'art rock': 'rock',
#  'symphonic rock': 'rock',
#  'roots rock': 'blues',
#  'garage rock': 'rock',
#  'modern alternative rock': 'rock',
#  'modern blues rock': 'blues',
#  'modern hard rock': 'rock',
#  'modern rock': 'rock',
#  'rockabilly': 'rock',
#  'kindie rock': 'rock',
#  'alternative rock': 'rock',
#  'electronic rock': 'house',
#  'indie rock': 'rock',
#  'hard rock': 'rock',
#  'rap rock': 'rock',
#  'blues rock': 'blues',
#  'heartland rock': 'rock',
#  'turkish rock': 'rock',
#  'rock steady': 'rock',
#  'alternative roots rock': 'blues',
#  'british indie rock': 'rock',
#  'dance rock': 'disco',
#  'british alternative rock': 'rock',
#  'welsh rock': 'rock',
#  'german rock': 'rock',
#  'pub rock': 'rock',
#  'southern rock': 'rock',
#  'pop rock': 'rock',
#  'traditional rockabilly': 'rock',
#  'sleaze rock': 'rock',
#  'neo-rockabilly': 'rock',
#  'uk rockabilly': 'rock',
#  'piano rock': 'rock',
#  'modern country rock': 'country',
#  'peruvian rock': 'rock',
#  'progressive rock': 'rock',
#  'reggae rock': 'rock',
#  'australian rock': 'rock',
#  'classic canadian rock': 'rock',
#  'industrial rock': 'rock',
#  'glam rock': 'rock',
#  'acid rock': 'rock',
#  'christian rock': 'rock',
#  'pittsburgh rock': 'rock',
#  'j-poprock': 'rock',
#  'irish rock': 'rock',
#  'australian alternative rock': 'rock',
#  'funk rock': 'disco',
#  'canadian rock': 'rock',
#  'gothic rock': 'rock',
#  'lovers rock': 'rock',
#  'celtic rock': 'rock',
#  'scottish rock': 'rock',
#  'anime rock': 'rock',
#  'mexican classic rock': 'rock',
#  'garage rock revival': 'rock',
#  'j-rock': 'rock',
#  'comedy rock': 'rock',
#  'punk rock italiano': 'rock',
#  'deathrock': 'rock',
#  'german hard rock': 'rock',
#  'swamp rock': 'rock',
#  'african rock': 'rock',
#  'german pop rock': 'rock',
#  'french rock': 'rock',
#  'rock drums': 'rock',
#  'psychedelic folk rock': 'rock',
#  'dutch rock': 'rock',
#  'modern folk rock': 'rock',
#  'rock keyboard': 'rock',
#  'spanish pop rock': 'rock',
#  'spanish rock': 'rock',
#  'latin rock': 'rock',
#  'mexican rock': 'rock',
#  'rock en espanol': 'rock',
#  'danish rock': 'rock',
#  'norwegian rock': 'rock',
#  'danish alternative rock': 'rock',
#  'danish pop rock': 'rock',
#  'experimental rock': 'rock',
#  'noise rock': 'rock',
#  'post-rock': 'rock',
#  'samba-rock': 'rock',
#  'south african rock': 'rock',
#  'colombian rock': 'rock',
#  'israeli rock': 'rock',
#  'german indie rock': 'rock',
#  'medieval rock': 'rock',
#  'instrumental rock': 'rock',
#  'idol rock': 'rock',
#  'suomi rock': 'rock',
#  'indie garage rock': 'rock',
#  'russian indie rock': 'rock',
#  'k-rock': 'rock',
#  'argentine rock': 'rock',
#  'indie rockism': 'rock',
#  'canadian rockabilly': 'rock',
#  'rock quebecois': 'rock',
#  'rock kapak': 'rock',
#  'chilean rock': 'rock',
#  'belgian rock': 'rock',
#  'classic j-rock': 'rock',
#  'turkish alternative rock': 'rock',
#  'krautrock': 'rock',
#  'croatian rock': 'rock',
#  'yugoslav rock': 'rock',
#  'jazz rock': 'jazz',
#  'greek psychedelic rock': 'rock',
#  'classic finnish rock': 'rock',
#  'icelandic rock': 'rock',
#  'portuguese rock': 'rock',
#  'space rock': 'rock',
#  'classic hungarian rock': 'rock',
#  'hungarian rock': 'rock',
#  'russian rock': 'rock',
#  'nordic post-rock': 'rock',
#  'stoner rock': 'rock',
#  'psychedelic blues-rock': 'blues',
#  'mexican rock-and-roll': 'rock',
#  'boston rock': 'rock',
#  'czech rock': 'rock',
#  'math rock latinoamericano': 'rock',
#  'italian progressive rock': 'rock',
#  'alternative pop rock': 'rock',
#  'rock andaluz': 'rock',
#  'finnish alternative rock': 'rock',
#  'punk rock mexicano': 'rock',
#  'swedish alternative rock': 'rock',
#  'instrumental math rock': 'rock',
#  'japanese post-rock': 'rock',
#  'brazilian rock': 'rock',
#  'rock alternativo brasileiro': 'rock',
#  'rock nacional brasileiro': 'rock',
#  'korean indie rock': 'rock',
#  'japanese punk rock': 'rock',
#  'latin surf rock': 'rock',
#  'german alternative rock': 'rock',
#  'english indie rock': 'rock',
#  'japanese alternative rock': 'rock',
#  'rock nacional': 'rock',
#  'modern southern rock': 'rock',
#  'power blues-rock': 'blues',
#  'rock progressif francais': 'rock',
#  'british post-rock': 'rock',
#  'cosmic post-rock': 'rock',
#  'spanish folk rock': 'rock',
#  'indorock': 'rock',
#  'swedish melodic rock': 'rock',
#  'polish rock': 'rock',
#  'irish indie rock': 'rock',
#  'rock independant francais': 'rock',
#  'swedish hard rock': 'rock',
#  'crack rock steady': 'rock',
#  'indie rock mexicano': 'rock',
#  'rock uruguayo': 'rock',
#  'future rock': 'rock',
#  'rock urbano mexicano': 'rock',
#  'instrumental stoner rock': 'rock',
#  'rockabilly en espanol': 'rock',
#  'swiss rock': 'rock',
#  'argentine alternative rock': 'rock',
#  'argentine indie rock': 'rock',
#  'puerto rican rock': 'rock',
#  'deep swedish rock': 'rock',
#  'pinoy rock': 'rock',
#  'deep christian rock': 'rock',
#  'finnish hard rock': 'rock',
#  'deep melodic hard rock': 'rock',
#  'australian indie rock': 'rock',
#  'rock cristiano': 'rock',
#  'chinese indie rock': 'rock',
#  'galician rock': 'rock',
#  'norwegian punk rock': 'rock',
#  'acoustic rock': 'rock',
#  'kiwi rock': 'rock',
#  'math rock': 'rock',
#  'british math rock': 'rock',
#  'canadian post-rock': 'rock',
#  'instrumental post-rock': 'rock',
#  'uk noise rock': 'rock',
#  'swedish stoner rock': 'rock',
#  'scottish indie rock': 'rock',
#  'rock chapin': 'rock',
#  'blues-rock guitar': 'blues',
#  'american post-rock': 'rock',
#  'polish post-rock': 'rock',
#  'cambodian rock': 'rock',
#  'thai indie rock': 'rock',
#  'melodic hard rock': 'rock',
#  'swedish psychedelic rock': 'rock',
#  'indian rock': 'rock',
#  'venezuelan rock': 'rock',
#  'geek rock': 'rock',
#  'norwegian alternative rock': 'rock',
#  'swedish indie rock': 'rock',
#  'austin rock': 'rock',
#  'hard rock brasileiro': 'rock',
#  'classic psychedelic rock': 'rock',
#  'action rock': 'rock',
#  'hard rock mexicano': 'rock',
#  'brazilian indie rock': 'rock',
#  'japanese garage rock': 'rock',
#  'ostrock': 'rock',
#  'ukrainian rock': 'rock',
#  'brazilian punk rock': 'rock',
#  'dutch punk rock': 'rock',
#  'neo-industrial rock': 'rock',
#  'rock paraense': 'rock',
#  'japanese psychedelic rock': 'rock',
#  'french stoner rock': 'rock',
#  'chinese post-rock': 'rock',
#  'japanese indie rock': 'rock',
#  'spanish modern rock': 'rock',
#  'belgian indie rock': 'rock',
#  'glam metal': 'metal',
#  'metal': 'metal',
#  'alternative metal': 'metal',
#  'groove metal': 'metal',
#  'industrial metal': 'metal',
#  'nu metal': 'metal',
#  'atlanta metal': 'metal',
#  'melodic metal': 'metal',
#  'neo classical metal': 'classical',
#  'power metal': 'metal',
#  'progressive metal': 'metal',
#  'swedish power metal': 'metal',
#  'swedish progressive metal': 'metal',
#  'metalcore': 'metal',
#  'german metal': 'metal',
#  'german power metal': 'metal',
#  'funk metal': 'disco',
#  'rap metal': 'metal',
#  'melodic metalcore': 'metal',
#  'j-metal': 'metal',
#  'comic metal': 'metal',
#  'death metal': 'metal',
#  'german thrash metal': 'metal',
#  'speed metal': 'metal',
#  'thrash metal': 'metal',
#  'nu-metalcore': 'metal',
#  'birmingham metal': 'metal',
#  'british power metal': 'metal',
#  'new wave of thrash metal': 'metal',
#  'canadian metal': 'metal',
#  'danish metal': 'metal',
#  'symphonic metal': 'metal',
#  'swedish metal': 'metal',
#  'metallic hardcore': 'metal',
#  'doom metal': 'metal',
#  'drone metal': 'metal',
#  'post-doom metal': 'metal',
#  'melodic death metal': 'metal',
#  'melodic groove metal': 'metal',
#  'swedish death metal': 'metal',
#  'celtic metal': 'metal',
#  'spanish folk metal': 'metal',
#  'spanish metal': 'metal',
#  'japanese power metal': 'metal',
#  'kawaii metal': 'metal',
#  'norwegian metal': 'metal',
#  'swedish metalcore': 'metal',
#  'french death metal': 'metal',
#  'french metal': 'metal',
#  'progressive groove metal': 'metal',
#  'canadian metalcore': 'metal',
#  'us power metal': 'metal',
#  'black metal': 'metal',
#  'norwegian black metal': 'metal',
#  'christian metal': 'metal',
#  'christian thrash metal': 'metal',
#  'finnish heavy metal': 'metal',
#  'neo-trad metal': 'metal',
#  'seattle metal': 'metal',
#  'brutal death metal': 'metal',
#  'florida death metal': 'metal',
#  'jazz metal': 'jazz',
#  'technical death metal': 'metal',
#  'british black metal': 'metal',
#  'chaotic black metal': 'metal',
#  'greek black metal': 'metal',
#  'greek metal': 'metal',
#  'post-metal': 'metal',
#  'uk doom metal': 'metal',
#  'australian metalcore': 'metal',
#  'gothic metal': 'metal',
#  'buffalo ny metal': 'metal',
#  'finnish metal': 'metal',
#  'finnish power metal': 'metal',
#  'gothic symphonic metal': 'metal',
#  'opera metal': 'metal',
#  'gothic black metal': 'metal',
#  'symphonic black metal': 'metal',
#  'atmospheric black metal': 'metal',
#  'denver metal': 'metal',
#  'japanese metalcore': 'metal',
#  'german metalcore': 'metal',
#  'gothenburg metal': 'metal',
#  'sludge metal': 'metal',
#  'stoner metal': 'metal',
#  'virginia metal': 'metal',
#  'uk metalcore': 'metal',
#  'argentine heavy metal': 'metal',
#  'latin metal': 'metal',
#  'retro metal': 'metal',
#  'japanese heavy metal': 'metal',
#  'southern metal': 'metal',
#  'american metalcore': 'metal',
#  'alabama metal': 'metal',
#  'christian metalcore': 'metal',
#  'melodic power metal': 'metal',
#  'austrian metal': 'metal',
#  'christian power metal': 'metal',
#  'north carolina metal': 'metal',
#  'brazilian groove metal': 'metal',
#  'brazilian metal': 'metal',
#  'brazilian thrash metal': 'metal',
#  'metal mineiro': 'metal',
#  'boston metal': 'metal',
#  'welsh metal': 'metal',
#  'progressive metalcore': 'metal',
#  'australian metal': 'metal',
#  'singaporean metal': 'metal',
#  'croatian metal': 'metal',
#  'new wave of glam metal': 'metal',
#  'pagan black metal': 'metal',
#  'progressive black metal': 'metal',
#  'viking black metal': 'metal',
#  'viking metal': 'metal',
#  'atmospheric post-metal': 'metal',
#  'dub metal': 'metal',
#  'autonomous black metal': 'metal',
#  'folk black metal': 'metal',
#  'scottish metal': 'metal',
#  'uk post-metal': 'metal',
#  'folk metal': 'metal',
#  'oulu metal': 'metal',
#  'irish metal': 'metal',
#  'avant-garde black metal': 'metal',
#  'avant-garde metal': 'metal',
#  'cascadian black metal': 'metal',
#  'post-black metal': 'metal',
#  'dark black metal': 'metal',
#  'french black metal': 'metal',
#  'technical black metal': 'metal',
#  'progressive power metal': 'metal',
#  'cavernous death metal': 'metal',
#  'portland metal': 'metal',
#  'italian folk metal': 'metal',
#  'italian power metal': 'metal',
#  'tolkien metal': 'metal',
#  'swedish heavy metal': 'metal',
#  'swedish doom metal': 'metal',
#  'indian metal': 'metal',
#  'slavic folk metal': 'metal',
#  'symphonic power metal': 'metal',
#  'german heavy metal': 'metal',
#  'pittsburgh metal': 'metal',
#  'vancouver metal': 'metal',
#  'brazilian heavy metal': 'metal',
#  'mexican metal': 'metal',
#  'mexican thrash metal': 'metal',
#  'peruvian metal': 'metal',
#  'russian metalcore': 'metal',
#  'cyber metal': 'metal',
#  'swedish black metal': 'metal',
#  'german black metal': 'metal',
#  'metal guitar': 'metal',
#  'norwegian death metal': 'metal',
#  'depressive black metal': 'metal',
#  'ukrainian metal': 'metal',
#  'australian black metal': 'metal',
#  'new wave of speed metal': 'metal',
#  'nz metal': 'metal',
#  'australian thrash metal': 'metal',
#  'italian metal': 'metal',
#  'instrumental progressive metal': 'metal',
#  'german death metal': 'metal',
#  'japanese black metal': 'metal',
#  'belfast metal': 'metal',
#  'metal nortista': 'metal',
#  'hungarian metal': 'metal',
#  'louisiana metal': 'metal',
#  'utah metal': 'metal',
#  'brazilian power metal': 'metal',
#  'metal tico': 'metal',
#  'slovenian metal': 'metal',
#  'metal uruguayo': 'metal',
#  'metal colombiano': 'metal',
#  'argentine metal': 'metal',
#  'italian heavy metal': 'metal',
#  'minneapolis metal': 'metal',
#  'metal baiano': 'metal',
#  'dutch death metal': 'metal',
#  'dutch metal': 'metal',
#  'black speed metal': 'metal',
#  'thrash-groove metal': 'metal',
#  'russian metal': 'metal',
#  'metal pernambucano': 'metal',
#  'metal paranaense': 'metal',
#  'indonesian black metal': 'metal',
#  'metal ecuatoriano': 'metal',
#  'chilean metal': 'metal',
#  'miami metal': 'metal',
#  'swiss metal': 'metal',
#  'metal cearense': 'metal',
#  'portuguese metal': 'metal',
#  'pinoy metal': 'metal',
#  'polish thrash metal': 'metal',
#  'russian thrash metal': 'metal',
#  'mexican death metal': 'metal',
#  'turkish metal': 'metal',
#  'dutch black metal': 'metal',
#  'brazilian death metal': 'metal',
#  'technical groove metal': 'metal',
#  'cleveland metal': 'metal',
#  'unblack metal': 'metal',
#  'chilean black metal': 'metal',
#  'arab metal': 'metal',
#  'baltic black metal': 'metal',
#  'estonian metal': 'metal',
#  'latvian metal': 'metal',
#  'austrian black metal': 'metal',
#  'danish black metal': 'metal',
#  'finnish death metal': 'metal',
#  'italian gothic metal': 'metal',
#  'slam death metal': 'metal',
#  'belgian metal': 'metal',
#  'canadian black metal': 'metal',
#  'acid jazz': 'jazz',
#  'nu jazz': 'jazz',
#  'jazz boom bap': 'jazz',
#  'indie jazz': 'jazz',
#  'smooth jazz': 'jazz',
#  'jazz funk': 'disco',
#  'vocal jazz': 'jazz',
#  'jazz blues': 'blues',
#  'indonesian jazz': 'jazz',
#  'soul jazz': 'blues',
#  'cool jazz': 'jazz',
#  'jazz': 'jazz',
#  'jazz piano': 'jazz',
#  'jazz rap': 'jazz',
#  'jazz violin': 'jazz',
#  'brazilian jazz': 'jazz',
#  'dinner jazz': 'jazz',
#  'french jazz': 'jazz',
#  'gypsy jazz': 'jazz',
#  'jazz guitar': 'jazz',
#  'jazztronica': 'jazz',
#  'japanese jazz': 'jazz',
#  'japanese jazz fusion': 'jazz',
#  'jazz fusion': 'jazz',
#  'electro jazz': 'house',
#  'norwegian contemporary jazz': 'jazz',
#  'norwegian jazz': 'jazz',
#  'swedish jazz': 'jazz',
#  'jazz trumpet': 'jazz',
#  'new orleans jazz': 'jazz',
#  'classic japanese jazz': 'jazz',
#  'jazz pop': 'jazz',
#  'jazz vibraphone': 'jazz',
#  'jazz harp': 'jazz',
#  'jazz saxophone': 'jazz',
#  'south african jazz': 'jazz',
#  'free jazz': 'jazz',
#  'contemporary jazz': 'jazz',
#  'ecm-style jazz': 'jazz',
#  'jazz drums': 'jazz',
#  'jazz clarinet': 'jazz',
#  'vintage jazz': 'jazz',
#  'avant-garde jazz': 'jazz',
#  'latin jazz': 'jazz',
#  'contemporary vocal jazz': 'jazz',
#  'jazz quartet': 'jazz',
#  'jazz trombone': 'jazz',
#  'jazz trio': 'jazz',
#  'danish jazz': 'jazz',
#  'italian jazz': 'jazz',
#  'straight-ahead jazz': 'jazz',
#  'turkish jazz': 'jazz',
#  'ethio-jazz': 'jazz',
#  'samba-jazz': 'jazz',
#  'spiritual jazz': 'jazz',
#  'israeli jazz': 'jazz',
#  'jazz double bass': 'jazz',
#  'west african jazz': 'jazz',
#  'portuguese jazz': 'jazz',
#  'belgian jazz': 'jazz',
#  'italian contemporary jazz': 'jazz',
#  'modern jazz trio': 'jazz',
#  'modern jazz piano': 'jazz',
#  'progressive jazz fusion': 'jazz',
#  'deep smooth jazz': 'jazz',
#  'german jazz': 'jazz',
#  'jazz flute': 'jazz',
#  'jazz orchestra': 'jazz',
#  'belgian modern jazz': 'jazz',
#  'jazz organ': 'jazz',
#  'japanese jazztronica': 'jazz',
#  'british jazz': 'jazz',
#  'uk contemporary jazz': 'jazz',
#  'canadian modern jazz': 'jazz',
#  'dark jazz': 'jazz',
#  'danish modern jazz': 'jazz',
#  'indian jazz': 'jazz',
#  'jazz cubano': 'jazz',
#  'ska jazz': 'jazz',
#  'scottish jazz': 'jazz',
#  'brazilian modern jazz': 'jazz',
#  'psychedelic jazz fusion': 'jazz',
#  'jazz tuba': 'jazz',
#  'deep jazz fusion': 'jazz',
#  'italian jazz fusion': 'jazz',
#  'japanese vocal jazz': 'jazz',
#  'jump blues': 'blues',
#  'rhythm and blues': 'blues',
#  'british blues': 'blues',
#  'delta blues': 'blues',
#  'blues': 'blues',
#  'chicago blues': 'blues',
#  'electric blues': 'blues',
#  'modern blues': 'blues',
#  'soul blues': 'blues',
#  'louisiana blues': 'blues',
#  'new orleans blues': 'blues',
#  'piano blues': 'blues',
#  'punk blues': 'blues',
#  'acoustic blues': 'blues',
#  'country blues': 'country',
#  'memphis blues': 'blues',
#  'traditional blues': 'blues',
#  'texas blues': 'blues',
#  'harmonica blues': 'blues',
#  'southern soul blues': 'blues',
#  'swamp blues': 'blues',
#  'rebel blues': 'blues',
#  'blues band': 'blues',
#  'canadian blues': 'blues',
#  'piedmont blues': 'house',
#  'garage punk blues': 'blues',
#  'malian blues': 'blues',
#  'gospel blues': 'blues',
#  'dutch blues': 'blues',
#  'australian blues': 'blues',
#  'polish blues': 'blues',
#  'disco': 'disco',
#  'post-disco': 'disco',
#  'disco house': 'house',
#  'italian disco': 'disco',
#  'nu disco': 'disco',
#  'deep discofox': 'disco',
#  'discofox': 'disco',
#  'deep disco': 'disco',
#  'deep italo disco': 'disco',
#  'deep disco house': 'house',
#  'post-disco soul': 'blues',
#  'dutch house': 'house',
#  'electro house': 'house',
#  'bass house': 'house',
#  'deep tropical house': 'house',
#  'progressive house': 'house',
#  'progressive trance house': 'house',
#  'filter house': 'house',
#  'uk house': 'house',
#  'acid house': 'house',
#  'microhouse': 'house',
#  'tech house': 'house',
#  'progressive electro house': 'house',
#  'chicago house': 'house',
#  'deep house': 'house',
#  'tribal house': 'house',
#  'vocal house': 'house',
#  'minimal tech house': 'house',
#  'tropical house': 'house',
#  'house': 'house',
#  'hip house': 'house',
#  'deep groove house': 'house',
#  'pop house': 'house',
#  'bouncy house': 'house',
#  'fidget house': 'house',
#  'diva house': 'house',
#  'future house': 'house',
#  'funky tech house': 'disco',
#  'garage house': 'house',
#  'dark progressive house': 'house',
#  'latin tech house': 'house',
#  'italo house': 'house',
#  'classic progressive house': 'house',
#  'outsider house': 'house',
#  'float house': 'house',
#  'dutch tech house': 'house',
#  'beach house': 'house',
#  'deep euro house': 'house',
#  'german tech house': 'house',
#  'organic house': 'house',
#  'witch house': 'house',
#  'hard house': 'house',
#  'lo-fi house': 'house',
#  'nordic house': 'house',
#  'german house': 'house',
#  'swedish tropical house': 'house',
#  'deep soul house': 'blues',
#  'detroit house': 'house',
#  'lounge house': 'house',
#  'italian tech house': 'house',
#  'brazilian house': 'house',
#  'french tech house': 'house',
#  'afro house': 'house',
#  'swiss house': 'house',
#  'latin house': 'house',
#  'deep tech house': 'house',
#  'deep progressive house': 'house',
#  'greek house': 'house',
#  'australian house': 'house',
#  'ambient house': 'house',
#  'brazilian tech house': 'house',
#  'uk tech house': 'house',
#  'canadian house': 'house',
#  'swedish house': 'house',
#  'mexican tech house': 'house',
#  'deep deep house': 'house',
#  'deep deep tech house': 'house',
#  'south african house': 'house',
#  'classical piano': 'classical',
#  'french classical piano': 'classical',
#  'classical': 'classical',
#  'polish classical': 'classical',
#  'finnish classical': 'classical',
#  'african-american classical': 'classical',
#  'norwegian classical': 'classical',
#  'classical era': 'classical',
#  'hindustani classical': 'classical',
#  'indian classical': 'classical',
#  'early modern classical': 'classical',
#  'baltic classical': 'classical',
#  'contemporary classical': 'classical',
#  'american contemporary classical': 'classical',
#  'classical performance': 'classical',
#  'neoclassical darkwave': 'classical',
#  'hungarian classical performance': 'classical',
#  'classical guitar': 'classical',
#  'greek contemporary classical': 'classical',
#  'neo-classical': 'classical',
#  '21st century classical': 'classical',
#  'british contemporary classical': 'classical',
#  'classical tenor': 'classical',
#  'spanish classical': 'classical',
#  'belgian contemporary classical': 'classical',
#  'american modern classical': 'classical',
#  'czech classical': 'classical',
#  'russian modern classical': 'classical',
#  'ukrainian classical': 'classical',
#  'classical trumpet': 'classical',
#  'latin classical': 'classical',
#  'brazilian classical': 'classical',
#  'british modern classical': 'classical',
#  'chinese classical performance': 'classical',
#  'icelandic classical': 'classical',
#  'classical mandolin': 'classical',
#  'canadian classical': 'classical',
#  'australian classical': 'classical',
#  'classical soprano': 'classical',
#  'italian classical piano': 'classical',
#  'japanese classical': 'classical',
#  'romanian contemporary classical': 'classical',
#  'nordic contemporary classical': 'classical',
#  'swedish contemporary classical': 'classical',
#  'portuguese contemporary classical': 'classical',
#  'american 21st century classical': 'classical',
#  'classical clarinet': 'classical',
#  'uk hip hop': 'hip hop',
#  'alternative hip hop': 'hip hop',
#  'hardcore hip hop': 'hip hop',
#  'underground hip hop': 'hip hop',
#  'conscious hip hop': 'hip hop',
#  'hip hop': 'hip hop',
#  'christian hip hop': 'hip hop',
#  'argentine hip hop': 'hip hop',
#  'nigerian hip hop': 'hip hop',
#  'portland hip hop': 'hip hop',
#  'detroit hip hop': 'hip hop',
#  'atl hip hop': 'hip hop',
#  'southern hip hop': 'hip hop',
#  'east coast hip hop': 'hip hop',
#  'indie hip hop': 'hip hop',
#  'abstract hip hop': 'hip hop',
#  'zim hip hop': 'hip hop',
#  'old school hip hop': 'hip hop',
#  'ohio hip hop': 'hip hop',
#  'ghanaian hip hop': 'hip hop',
#  'canadian hip hop': 'hip hop',
#  'queens hip hop': 'hip hop',
#  'oakland hip hop': 'hip hop',
#  'bronx hip hop': 'hip hop',
#  'miami hip hop': 'hip hop',
#  'latin hip hop': 'hip hop',
#  'political hip hop': 'hip hop',
#  'spiritual hip hop': 'hip hop',
#  'boston hip hop': 'hip hop',
#  'virginia hip hop': 'hip hop',
#  'harlem hip hop': 'hip hop',
#  'dutch hip hop': 'hip hop',
#  'mexican hip hop': 'hip hop',
#  'scottish hip hop': 'hip hop',
#  'deep german hip hop': 'hip hop',
#  'german hip hop': 'hip hop',
#  'minnesota hip hop': 'hip hop',
#  'jewish hip hop': 'hip hop',
#  'french hip hop': 'hip hop',
#  'venezuelan hip hop': 'hip hop',
#  'asian american hip hop': 'hip hop',
#  'north carolina hip hop': 'hip hop',
#  'deep underground hip hop': 'hip hop',
#  'polish hip hop': 'hip hop',
#  'italian hip hop': 'hip hop',
#  'psychedelic hip hop': 'hip hop',
#  'bangladeshi hip hop': 'hip hop',
#  'bay area hip hop': 'hip hop',
#  'nashville hip hop': 'hip hop',
#  'swiss hip hop': 'hip hop',
#  'kenyan hip hop': 'hip hop',
#  'bc underground hip hop': 'hip hop',
#  'brazilian hip hop': 'hip hop',
#  'czech hip hop': 'hip hop',
#  'desi hip hop': 'hip hop',
#  'tamil hip hop': 'hip hop',
#  'mississippi hip hop': 'hip hop',
#  'tennessee hip hop': 'hip hop',
#  'kentucky hip hop': 'hip hop',
#  'buffalo hip hop': 'hip hop',
#  'australian underground hip hop': 'hip hop',
#  'experimental hip hop': 'hip hop',
#  'arkansas hip hop': 'hip hop',
#  'lgbtq+ hip hop': 'hip hop',
#  'australian hip hop': 'hip hop',
#  'memphis hip hop': 'hip hop',
#  'kansas city hip hop': 'hip hop',
#  'hong kong hip hop': 'hip hop',
#  'seattle hip hop': 'hip hop',
#  'austin hip hop': 'hip hop',
#  'flint hip hop': 'hip hop',
#  'industrial hip hop': 'hip hop',
#  'spanish hip hop': 'hip hop',
#  'sacramento hip hop': 'hip hop',
#  'native american hip hop': 'hip hop',
#  'thai hip hop': 'hip hop',
#  'hawaiian hip hop': 'hip hop',
#  'colombian hip hop': 'hip hop',
#  'uk alternative hip hop': 'hip hop',
#  'south african hip hop': 'hip hop',
#  'nz hip hop': 'hip hop',
#  'birmingham hip hop': 'hip hop',
#  'pakistani hip hop': 'hip hop',
#  'punjabi hip hop': 'hip hop',
#  'indonesian hip hop': 'hip hop',
#  'swedish hip hop': 'hip hop',
#  'hindi hip hop': 'hip hop',
#  'persian hip hop': 'hip hop',
#  'chinese hip hop': 'hip hop',
#  'deep east coast hip hop': 'hip hop',
#  'taiwan hip hop': 'hip hop',
#  'indiana hip hop': 'hip hop',
#  'vietnamese hip hop': 'hip hop',
#  'baltimore hip hop': 'hip hop',
#  'peruvian hip hop': 'hip hop',
#  'arabic hip hop': 'hip hop',
#  'west australian hip hop': 'hip hop',
#  'milwaukee hip hop': 'hip hop',
#  'russian hip hop': 'hip hop',
#  'irish hip hop': 'hip hop',
#  'hip hop tuga': 'hip hop',
#  'cologne hip hop': 'hip hop',
#  'canadian indigenous hip hop': 'hip hop',
#  'south carolina hip hop': 'hip hop',
#  'rwandan hip hop': 'hip hop',
#  'italian underground hip hop': 'hip hop',
#  'norwegian hip hop': 'hip hop',
#  'danish hip hop': 'hip hop',
#  'contemporary country': 'country',
#  'country': 'country',
#  'country road': 'country',
#  'outlaw country': 'country',
#  'classic country pop': 'country',
#  'truck-driving country': 'country',
#  'oklahoma country': 'country',
#  'arkansas country': 'country',
#  'country dawn': 'country',
#  'alternative country': 'country',
#  'country pop': 'country',
#  'country gospel': 'country',
#  'canadian country': 'country',
#  'texas country': 'country',
#  'queer country': 'country',
#  'norwegian country': 'country',
#  'traditional country': 'country',
#  'alberta country': 'country',
#  'canadian contemporary country': 'country',
#  'australian country': 'country',
#  'classic australian country': 'country',
#  'swedish country': 'country',
#  'country rap': 'country',
#  'neo-traditional country': 'country',
#  'deep contemporary country': 'country',
#  'country boogie': 'country',
#  'irish country': 'country',
#  'german country': 'country',
#  'manitoba country': 'country',
#  'classic nz country': 'country',
#  'british country': 'country',
#  'south african country': 'country',
#  'early romantic era': 'classical',
#  'post-romantic era': 'classical',
#  'late romantic era': 'classical',
#  'russian romanticism': 'classical',
#  'american romanticism': 'classical',
#  'new romantic': 'classical',
#  'italian romanticism': 'classical',
#  'french romanticism': 'classical',
#  'german romanticism': 'classical',
#  'pop romantico': 'classical',
#  'romantico': 'classical',
#  'batidao romantico': 'classical',
#  'baroque': 'classical',
#  'german baroque': 'classical',
#  'spanish baroque': 'classical',
#  'italian baroque': 'classical',
#  'english baroque': 'classical',
#  'baroque pop': 'classical',
#  'modern funk': 'disco',
#  'funk': 'disco',
#  'g funk': 'disco',
#  'brit funk': 'disco',
#  'new orleans funk': 'disco',
#  'p funk': 'disco',
#  'synth funk': 'disco',
#  'instrumental funk': 'disco',
#  'funk carioca': 'disco',
#  'afro-funk': 'disco',
#  'deep funk': 'disco',
#  'traditional funk': 'disco',
#  'funk 150 bpm': 'disco',
#  'future funk': 'disco',
#  'drumfunk': 'disco',
#  'liquid funk': 'disco',
#  'rave funk': 'disco',
#  'uk funky': 'disco',
#  'latin funk': 'disco',
#  'funk ostentacao': 'disco',
#  'trap funk': 'disco',
#  'cumbia funk': 'disco',
#  'brega funk': 'disco',
#  'funky breaks': 'disco',
#  'deep g funk': 'disco',
#  'funk consciente': 'disco',
#  'funk paulista': 'disco',
#  'funk das antigas': 'disco',
#  'funk mexicano': 'disco',
#  'funk pop': 'disco',
#  'neurofunk': 'disco',
#  'dance pop': 'disco',
#  'pop dance': 'disco',
#  'alternative dance': 'disco',
#  'dance-punk': 'disco',
#  'afro dancehall': 'disco',
#  'australian dance': 'disco',
#  'eurodance': 'disco',
#  'belgian dance': 'disco',
#  'zimdancehall': 'disco',
#  'haitian dance': 'disco',
#  'guidance': 'disco',
#  'kids dance party': 'disco',
#  'j-dance': 'disco',
#  'bubblegum dance': 'disco',
#  'dancehall': 'disco',
#  'old school dancehall': 'disco',
#  'german dance': 'disco',
#  'uk dance': 'disco',
#  'italo dance': 'disco',
#  'russian dance pop': 'disco',
#  'uk dancehall': 'disco',
#  'braindance': 'disco',
#  'intelligent dance music': 'disco',
#  'finnish dance pop': 'disco',
#  'british dance band': 'disco',
#  'irish dance': 'disco',
#  'christian dance': 'disco',
#  'belly dance': 'disco',
#  'swedish dancehall': 'disco',
#  'russian dance': 'disco',
#  'electropop': 'house',
#  'electronica': 'house',
#  'electropowerpop': 'house',
#  'arab electronic': 'house',
#  'electro': 'house',
#  'hamburg electronic': 'house',
#  'munich electronic': 'house',
#  'bulgarian electronic': 'house',
#  'nz electronic': 'house',
#  'electronic trap': 'house',
#  'australian electropop': 'house',
#  'indie electropop': 'house',
#  'ukrainian electronic': 'house',
#  'electroclash': 'house',
#  'vintage french electronic': 'house',
#  'electro swing': 'house',
#  'electro latino': 'house',
#  'indian electronic': 'house',
#  'electrofox': 'house',
#  'scottish electronic': 'house',
#  'uk experimental electronic': 'house',
#  'power electronics': 'house',
#  'experimental electronic': 'house',
#  'organic electronic': 'house',
#  'electro-industrial': 'house',
#  'electronica argentina': 'house',
#  'pop electronico': 'house',
#  'canadian electronic': 'house',
#  'canadian electropop': 'house',
#  'slovenian electronic': 'house',
#  'japanese electronic': 'house',
#  'swedish electropop': 'house',
#  'italian electronica': 'house',
#  'electro dub': 'house',
#  'cologne electronic': 'house',
#  'chinese electropop': 'house',
#  'cuban electronic': 'house',
#  'danish electronic': 'house',
#  'spanish electronic': 'house',
#  'electro-pop francais': 'house',
#  'dark electro': 'house',
#  'bristol electronic': 'house',
#  'electronica cristiana': 'house',
#  'electronic djent': 'house',
#  'dusseldorf electronic': 'house',
#  'romanian electronic': 'house',
#  'swedish electronic': 'house',
#  'african electronic': 'house',
#  'german electronica': 'house',
#  'georgian electronic': 'house',
#  'electroacoustic composition': 'house',
#  'lithuanian electronic': 'house',
#  'belarusian electronic': 'house',
#  'macedonian electronic': 'house',
#  'frankfurt electronic': 'house',
#  'electronica venezuela': 'house',
#  'electro trash': 'house',
#  'indie electronica': 'house',
#  'edm': 'house',
#  'turkish edm': 'house',
#  'mexican edm': 'house',
#  'belgian edm': 'house',
#  'brazilian edm': 'house',
#  'dutch edm': 'house',
#  'pop edm': 'house',
#  'gaming edm': 'house',
#  'russian edm': 'house',
#  'indian edm': 'house',
#  'cedm': 'house',
#  'finnish edm': 'house',
#  'edmonton indie': 'house',
#  'deep pop edm': 'house',
#  'indonesian edm': 'house',
#  'kawaii edm': 'house',
#  'french techno': 'house',
#  'minimal techno': 'house',
#  'techno': 'house',
#  'bleep techno': 'house',
#  'german techno': 'house',
#  'hardcore techno': 'house',
#  'minimal melodic techno': 'house',
#  'indian techno': 'house',
#  'techno kayo': 'house',
#  'swedish techno': 'house',
#  'dub techno': 'house',
#  'proto-techno': 'house',
#  'melodic techno': 'house',
#  'detroit techno': 'house',
#  'raw techno': 'house',
#  'destroy techno': 'house',
#  'experimental techno': 'house',
#  'belgian techno': 'house',
#  'dark minimal techno': 'house',
#  'ambient techno': 'house',
#  'deep minimal techno': 'house',
#  'dark techno': 'house',
#  'japanese techno': 'house',
#  'spanish techno': 'house',
#  'scottish techno': 'house',
#  'deep techno': 'house',
#  ...}

# %% [markdown]
# On obtient un dictionnaire où chaque sous-genre renvoie vers son genre parent
#
# Rassemblons maintenant les chansons par genre musical

# %%
tracksByGenre = {}

for trackId, trackInfo in tracksDict.items():
    
    trackGenre = ''
    
    # On parcourt les sous genres associés au morceau
    for trackSubgenres in trackInfo['genres'] :
        # Si un sous genre est présent dans le dictionnaire rassemblant les sous genres qui nous intéressent
        if subgenresToGenre.get(trackSubgenres) :
            # On assigne ce genre au morceau et on arrête de parcourir les sous genres associés au morceau
            trackGenre = subgenresToGenre.get(trackSubgenres)
            break
            
    # Si l'on a assigné un genre au morceau, alors on l'ajoute à notre nouveau dictionnaire avec les infos correspondantes
    if trackGenre :
        tracksByGenre[trackId] = {'track_name' : trackInfo['track_name'],
                                  'track_artists' : trackInfo['track_artists'],
                                  'genre' : trackGenre}

# %% [markdown]
# On formate ensuite nos données sous forme de dataframe pandas

# %%
tracksDatabase = pd.DataFrame(tracksByGenre).transpose()

tracksDatabase.genre.value_counts()
# Out:
# rock         9028
# classical    4651
# country      3294
# disco        3255
# hip hop      3178
# metal        2356
# jazz         2163
# blues        2065
# house        1755
# Name: genre, dtype: int64

# %% [markdown]
# On observe que même en boostant quelques genres musicaux (notamment electro-house) il est difficile d'augmenter leur nombre. On obtient tout de même au moins 1750 morceaux de chaque genre, ce qui peut nous permettre de constituer une base de données de plus de 15000 musiques différentes à classer. Cela nous semble raisonnable pour continuer.

# %%
def balance_database (database, numPerClass, genreList):
    
    balancedDb = pd.DataFrame()
    
    for genre in genreList :
        
        filteredIndex = rd.sample(list(database[database.genre == genre].index), k = numPerClass)
        balancedGenre = database.loc[filteredIndex]
        
        balancedDb = pd.concat([balancedDb, balancedGenre], axis = 0)
        
    return balancedDb

# %% [markdown]
# La fonction prend en argument la base de données déséquilibrées, le nombre de musiques que l'on veut par classe et le nom de chaque classe (les genres musicaux) et retourne une base de données équilibrée constituée aléatoirement

# %%
tracksDatabaseBalanced = balance_database(tracksDatabase, 
                                          numPerClass = tracksDatabase.genre.value_counts()[-1],
                                          genreList = genres)

# On vérifie bien que la base est équilibrée
print(len(tracksDatabaseBalanced))

print("\nNb of tracks per genres :")
print(tracksDatabaseBalanced.genre.value_counts())

print("\nAll tracks are represented only once :")
print(tracksDatabaseBalanced.index.value_counts())
# Out:
# 15795
#
# Nb of tracks per genres :
# disco        1755
# hip hop      1755
# rock         1755
# metal        1755
# country      1755
# house        1755
# jazz         1755
# classical    1755
# blues        1755
# Name: genre, dtype: int64
#
# All tracks are represented only once :
# 3RrumTYvxSLX8SwLrZCjNd    1
# 1TrGdXSgiBm8W68D2K1COG    1
# 6ZRnVnjp57UMZPQqVLMZgS    1
# 6DHrIQHwu9GRrqzocQvONi    1
# 2lCY26XhIuoDGJolzRIyd3    1
#                          ..
# 1wGYcpJZ59rePkNu4zHmLu    1
# 5zIt9z09XeV59kTyZ6tTbq    1
# 7CsQdepFbZSNrisMKeZffg    1
# 4ARyqqJXPiHpqVbLtF6XEb    1
# 6kyV55FlbuERNL3YK2RivS    1
# Length: 15795, dtype: int64

# %% [markdown]
# On a donc réussi à rassembler les indentifiants de 1755 chansons différentes pour chacun de nos 9 genres, en élargissant un peu certaines familles (house/electro/techno ou disco/funk par exemple).
#
# Il nous faut maintenant récupérer les features et les extraits de chacun de ces chansons.

# %%
def get_spotify_features (tracksDb, spotify_module, 
                          savename = 'Data//spotify_features.csv',
                          dropFields = ['type', 'uri', 'track_href', 'analysis_url']):
    
    # On crée un dictionnaire avec pour index les identifiants des chansons
    # Et pour valeur le dictionnaire correspondant qui contient le nom de la musique, l'artiste et le genre associés
    featuresDict = {trackId : dict(tracksDb.loc[trackId]) for trackId in tracksDb.index}
    
    for trackId, trackInfos in featuresDict.items():
        
        # Pour chaque identifiant, on récupère les features spotify
        track_features = spotify_module.audio_features(trackId)[0]
        
        # Parfois, mais très rarement, la liste des features est vide. 
        # On ne l'ajoute à la base que si la liste n'est pas vide
        if track_features :
            trackInfos.update(track_features)
            
    # On transforme le dictionnaire en dataframae
    features_df = pd.DataFrame(featuresDict).transpose().drop(dropFields, axis = 1)
    features_df.to_csv('%s.csv' % savename, index = False)
    
    return features_df

# %%
#spotify_features = get_spotify_features(tracksDatabaseBalanced, sp)

# %% [markdown]
# L'API de spotify permet également de récupérer des éléments "d'analyse" effectués par spotify. On retrouve par exemple la durée estimée des mesures ou le nombre de battements par minute (une estimation du tempo). Ce qui nous intéresse, ce sont la liste des estimations des hauteurs des notes au cours du temps (leur emplacement dans la gamme) ainsi que leur timbre respectif (leur "aspect" musical).
#
# Un problème est que, puisque le tempo et la durée des musiques est différentes, la longueur des listes contenant les timbres et les hauteurs sont différentes. Pour pallier cela, nous avons choisi de ne récupérer les informations que des 1500 premières notes. Suivant le tempo de la musique et les notes jouées, les 1500 premières notes correspondent à environ 25 à 50 secondes au début de la chanson. On peut imaginer cette durée largement suffisante pour estimer le genre d'une musique, l'oreille humaine y parvenant généralement en quelques secondes.

# %%
def get_spotify_analysis (tracksDb, spotify_module, 
                          savedNotes = 1500,
                          savename = 'Data//spotify_analysis'):
    
    # On crée deux dictionnaires qui contiendront les listes des hauteurs ou des timbres pour chaque piste
    pitchesDict = {}
    timbresDict = {}
    
    # Pour chaque piste, on récupère l'analyse de spotify
    for trackId in tracksDb.index:
        
        # On ajoute une exception car parfois la recherche de l'analyse provoque une erreur HTTP sans que l'on comprennne pourquoi
        # Probablement parce que l'analyse n'est pas disponible pour cette piste
        try : 
            trackAnalysis = spotify_module.audio_analysis(trackId)
            
            # On ne s'intéresse qu'aux savedNotes/12 premiers segments, car les segments sont rassemblés en groupe de 12 notes
            # On ajoute les hauteurs et les timbres des premières notes si et seulement si la longueur est suffisante. 
            if len(trackAnalysis['segments']) >= savedNotes//12 :
                pitchesDict[trackId] = []
                timbresDict[trackId] = []
            
                for segment in trackAnalysis['segments'][:savedNotes//12]:
                    pitchesDict[trackId].extend(segment['pitches'])
                    timbresDict[trackId].extend(segment['timbre'])
        except :
            print('HTTP Error for : ', trackId)
            
        # On sauvegarde ensuite le dictionnaire à chaque étape, car les calculs sont longs et les erreurs fréquentes
        
        with open('%s_pitches.pickle' % savename, 'wb') as dict_file:
            pickle.dump(pitchesDict, dict_file, protocol=pickle.HIGHEST_PROTOCOL)
            
        with open('%s_timbres.pickle' % savename, 'wb') as dict_file:
            pickle.dump(timbresDict, dict_file, protocol=pickle.HIGHEST_PROTOCOL)  
            
    pitches_df = pd.DataFrame(pitchesDict).transpose()
    timbres_df = pd.DataFrame(timbresDict).transpose()
    
    pitches_df.to_csv('%s_pitches.csv' % savename, index = False)
    timbres_df.to_csv('%s_timbres.csv' % savename, index = False)
    
    return pitches_df, timbres_df

# %%
# pitches_df, timbres_df = get_spotify_analysis(tracksDatabaseBalanced, sp)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-analysis/54T5ibGnwfdM5ez7xqwJQl returned 404 due to analysis not found
# HTTP Error for :  54T5ibGnwfdM5ez7xqwJQl
# HTTP Error for GET to https://api.spotify.com/v1/audio-analysis/0M2hkIRjThYwmhgPYBBVWg returned 404 due to analysis not found
# HTTP Error for :  0M2hkIRjThYwmhgPYBBVWg
# Max Retries reached
# HTTP Error for :  3XhM0bJQzMH0fWmGepafYA
# Max Retries reached
# HTTP Error for :  6N3BEQOuCDf701cMMMfKMn
# HTTP Error for :  6XAlmnkpNnwDJK4rRlAi1f
# HTTP Error for :  3NMaN8bp1QlzVXJCF22Fgv
# HTTP Error for GET to https://api.spotify.com/v1/audio-analysis/4YW7G6KNkM9JoB7SLB3MZM returned 404 due to analysis not found
# HTTP Error for :  4YW7G6KNkM9JoB7SLB3MZM

# %% [markdown]
# On constate quelques erreurs mais dans l'ensemble on a réussi à récupérer les données pour la plupart des pistes

# %%
print("Nombre de pistes dont on a pu obtenir les données d'analyses :", len(pitches_df))
print('Si in seul index différe, la somme sera différente de 0 :', sum(pitches_df.index != timbres_df.index))
# Out:
# Nombre de pistes dont on a pu obtenir les données d'analyses : 15741
# Si in seul index différe, la somme sera différente de 0 : 0

# %% [markdown]
# On voit bien que les index sont identiques, et on dispose au total de 15741 morceaux différents.
#
# On ajoute simplement les labels aux deux dataframe timbres et hauteurs :

# %%
for trackIdx in pitches_df.index :
    trackGenre = tracksDatabaseBalanced.loc[trackIdx, 'genre']
    pitches_df.loc[trackIdx, 'genre'] = trackGenre
    timbres_df.loc[trackIdx, 'genre'] = trackGenre

# %% [markdown]
# On va rééquilibrer la base de données une dernière fois, puisque les données d'analyses n'étaient pas disponibles pour certaines pistes :

# %%
pitches_df.genre.value_counts()
# Out:
# disco        1755
# hip hop      1755
# country      1755
# blues        1755
# rock         1753
# house        1753
# jazz         1753
# metal        1751
# classical    1711
# Name: genre, dtype: int64

# %%
pitches_df_final = balance_database(pitches_df, 
                                    numPerClass = pitches_df.genre.value_counts()[-1], 
                                    genreList = genres)

# %% [markdown]
# Les données sont bien équilibrées :

# %%
pitches_df_final.genre.value_counts()
# Out:
# disco        1711
# hip hop      1711
# rock         1711
# metal        1711
# country      1711
# house        1711
# jazz         1711
# classical    1711
# blues        1711
# Name: genre, dtype: int64

# %% [markdown]
# On ajuste les deux autres dataframe en accord avec celui contenant les hauteurs des notes

# %%
timbres_df_final = timbres_df[timbres_df.index.isin(pitches_df_final.index)]
tracksDatabaseFinal = tracksDatabaseBalanced[tracksDatabaseBalanced.index.isin(pitches_df_final.index)]

# %% [markdown]
# On sauvegarde enfin les bases terminées :

# %%
pitches_df_final.to_csv("Data//tracksPitches.csv")
timbres_df_final.to_csv("Data//tracksTimbres.csv")
tracksDatabaseFinal.to_csv("Data//tracksMeta.csv")
